# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique(axis=0)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
application_df['APPLICATION_TYPE'].value_counts().keys().tolist()
# Out:
# ['T3',
#  'T4',
#  'T6',
#  'T5',
#  'T19',
#  'T8',
#  'T7',
#  'T10',
#  'T9',
#  'T13',
#  'T12',
#  'T2',
#  'T25',
#  'T14',
#  'T29',
#  'T15',
#  'T17']

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<1883].keys().tolist()
# Out:
# ['C7000',
#  'C1700',
#  'C4000',
#  'C5000',
#  'C1270',
#  'C2700',
#  'C2800',
#  'C7100',
#  'C1300',
#  'C1280',
#  'C1230',
#  'C1400',
#  'C7200',
#  'C2300',
#  'C1240',
#  'C8000',
#  'C7120',
#  'C1500',
#  'C1800',
#  'C6000',
#  'C1250',
#  'C8200',
#  'C1238',
#  'C1278',
#  'C1235',
#  'C1237',
#  'C7210',
#  'C2400',
#  'C1720',
#  'C4100',
#  'C1257',
#  'C1600',
#  'C1260',
#  'C2710',
#  'C0',
#  'C3200',
#  'C1234',
#  'C1246',
#  'C1267',
#  'C1256',
#  'C2190',
#  'C4200',
#  'C2600',
#  'C5200',
#  'C1370',
#  'C1248',
#  'C6100',
#  'C1820',
#  'C1900',
#  'C1236',
#  'C3700',
#  'C2570',
#  'C1580',
#  'C1245',
#  'C2500',
#  'C1570',
#  'C1283',
#  'C2380',
#  'C1732',
#  'C1728',
#  'C2170',
#  'C4120',
#  'C8210',
#  'C2561',
#  'C4500',
#  'C2150']

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = application_df['CLASSIFICATION'].value_counts().loc[lambda x : x<1883].keys().tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df = application_df.drop(columns={'STATUS','SPECIAL_CONSIDERATIONS'})

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df)
application_dummies.head()
# Out:
#    ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0     5000              1                       0                     1
# 1   108590              1                       0                     0
# 2     5000              0                       0                     0
# 3     6692              1                       0                     0
# 4   142590              1                       0                     0
#
#    APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                     0                    0                    0
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     0                    1                    0
#
#    APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = application_dummies['IS_SUCCESSFUL']
X = application_dummies.drop(['IS_SUCCESSFUL'],axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=16)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_features = len(X_train_scaled[0])
# Variables to store the number of nodes per layer
hidden_node_layer_1 = 80
hidden_node_layer_2 = 60

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_node_layer_1, input_dim=num_features, activation='relu'))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units=hidden_node_layer_2, activation='relu'))

# Output layer
nn1.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_8 (Dense)             (None, 80)                3280
#
#  dense_9 (Dense)             (None, 60)                4860
#
#  dense_10 (Dense)            (None, 1)                 61
#
# ...
# Total params: 8,201
# Trainable params: 8,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn1.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn1.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 555us/step - loss: 0.5697 - accuracy: 0.7213
# Epoch 2/200
# 804/804 [==============================] - 0s 517us/step - loss: 0.5560 - accuracy: 0.7264
# Epoch 3/200
# 804/804 [==============================] - 0s 517us/step - loss: 0.5536 - accuracy: 0.7302
# Epoch 4/200
# 804/804 [==============================] - 0s 518us/step - loss: 0.5518 - accuracy: 0.7288
# Epoch 5/200
# 804/804 [==============================] - 0s 518us/step - loss: 0.5515 - accuracy: 0.7303
# Epoch 6/200
# 804/804 [==============================] - 0s 527us/step - loss: 0.5500 - accuracy: 0.7317
# Epoch 7/200
# 804/804 [==============================] - 0s 549us/step - loss: 0.5490 - accuracy: 0.7306
# Epoch 8/200
# 804/804 [==============================] - 0s 516us/step - loss: 0.5486 - accuracy: 0.7321
# Epoch 9/200
# 804/804 [==============================] - 0s 519us/step - loss: 0.5476 - accuracy: 0.7319
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5768 - accuracy: 0.7318 - 154ms/epoch - 575us/step
# Loss: 0.5767728090286255, Accuracy: 0.7317784428596497

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
num_features = len(X_train_scaled[0])
# Variables to store the number of nodes per layer
hidden_node_layer_1 = 80
hidden_node_layer_2 = 30
hidden_node_layer_3 = 10

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_node_layer_1, input_dim=num_features, activation='relu'))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_node_layer_2, activation='relu'))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_node_layer_2, activation='relu'))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_11 (Dense)            (None, 80)                3280
#
#  dense_12 (Dense)            (None, 30)                2430
#
#  dense_13 (Dense)            (None, 30)                930
#
#  dense_14 (Dense)            (None, 1)                 31
#
# ...
# Total params: 6,671
# Trainable params: 6,671
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn2.fit(X_train_scaled,y_train,epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 572us/step - loss: 0.5715 - accuracy: 0.7186
# Epoch 2/200
# 804/804 [==============================] - 0s 557us/step - loss: 0.5553 - accuracy: 0.7298
# Epoch 3/200
# 804/804 [==============================] - 0s 555us/step - loss: 0.5529 - accuracy: 0.7302
# Epoch 4/200
# 804/804 [==============================] - 0s 553us/step - loss: 0.5508 - accuracy: 0.7311
# Epoch 5/200
# 804/804 [==============================] - 0s 555us/step - loss: 0.5496 - accuracy: 0.7318
# Epoch 6/200
# 804/804 [==============================] - 0s 583us/step - loss: 0.5497 - accuracy: 0.7309
# Epoch 7/200
# 804/804 [==============================] - 0s 562us/step - loss: 0.5485 - accuracy: 0.7332
# Epoch 8/200
# 804/804 [==============================] - 0s 567us/step - loss: 0.5475 - accuracy: 0.7336
# Epoch 9/200
# 804/804 [==============================] - 0s 559us/step - loss: 0.5475 - accuracy: 0.7335
# Epoch 10/200
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5592 - accuracy: 0.7320 - 153ms/epoch - 569us/step
# Loss: 0.5592317581176758, Accuracy: 0.7320116758346558

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=10,
        step=2), activation=activation, input_dim=len(X_train_scaled[0])))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=10,
            step=2),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=30,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled, y_train, epochs = 30, validation_data=(X_test_scaled,y_test))
# Out:
# Trial 180 Complete [00h 00m 20s]
# val_accuracy: 0.7334110736846924
#
# Best val_accuracy So Far: 0.7338775396347046
# Total elapsed time: 00h 13m 44s
# INFO:tensorflow:Oracle triggered exit

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'tanh',
#  'first_units': 9,
#  'num_layers': 6,
#  'units_0': 7,
#  'units_1': 3,
#  'units_2': 7,
#  'units_3': 5,
#  'units_4': 7,
#  'units_5': 5,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 1,
#  'tuner/trial_id': '0152'}

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5527 - accuracy: 0.7339 - 242ms/epoch - 903us/step
# Loss: 0.5527099967002869, Accuracy: 0.7338775396347046

# %%
# Export our model to HDF5 file

nn1.save('AlphabetSoupCharity_Optimisation1.h5')
nn2.save('AlphabetSoupCharity_Optimisation2.h5')
best_model.save('AlphabetSoupCharity_Optimisation3.h5')
